# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.graph_objs as go
import plotly
import plotly.offline as py
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 1. Data Cleaning and Processing

# %%
# Reading the data 
df = pd.read_csv("../BiotechEfSet.csv")

# Dropping the unnecessary columns
df.drop('Unnamed: 0', axis=1, inplace=True)

# Sorting the data by CEFR level
df.sort_values(by=['CEFR_level'], inplace=True)

# Resetting the index
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                            Name  EF_Score CEFR_level  Listening_score  \
# 0                     karthik p        30         A1               28
# 1                  Rashmitha  V        37         A2               44
# 2         Theevika K Theevika K        32         A2               28
# 3                DHIVYA GOMATHI        38         A2               46
# 4                     NITHYA  R        47         B1               37
# 5            Rajalakshmi Ponraj        49         B1               44
# 6                      Harini k        46         B1               44
# 7           Keerthana  Arumugam        47         B1               46
# 8             SWATHI V SWATHI V        50         B1               43
# 9       GIFTY GNANA SINTHIYA. K        55         B2               58
# 10               Stephen Daniel        57         B2               56
# 11                     swetha s        53         B2               46
# 12  SARAL JASMIN  SANTHOSHINI A        58         B2               57
# 13                    Hallina M        53         B2               49
# 14               Harini Sridhar        59         B2               57
# 15                   Subashni S        69         C1               72
# 16               SHANGAMITHRA S        62         C1               64
# 17            Sashmitha  Marian        66         C1               64
# 18           Thomas Santhoshni         65         C1               64
# 19                    Advika  J        63         C1               55
# 20                    Yazhini A        69         C1               72
# 21                    karthik s        68         C1               64
# 22                 Ferlinsa Max        62         C1               51
# 23                   BHAVASRI S        62         C1               60
# 24               AMSAPRABA  A P        63         C1               58
# 25                Mayuri Arvind        64         C1               68
# 26                    Akshaya A        63         C1               60
# 27              JOSELIN REINA J        71         C2               68
# 28                 Jayashri B.S        72         C2               68
# 29              Bernita Celas C        72         C2               72
#
#    Listening_scale  Reading_score Reading_scale
# 0               A1             32            A2
# 1               B1             30            A1
# 2               A1             35            A2
# 3               B1             30            A1
# 4               A2             57            B2
# 5               B1             53            B2
# 6               B1             48            B1
# 7               B1             47            B1
# 8               B1             57            B2
# 9               B2             52            B2
# 10              B2             57            B2
# 11              B1             59            B2
# 12              B2             59            B2
# 13              B1             56            B2
# 14              B2             60            B2
# 15              C2             65            C1
# 16              C1             60            B2
# 17              C1             67            C1
# 18              C1             65            C1
# 19              B2             71            C2
# 20              C2             65            C1
# 21              C1             71            C2
# 22              B2             72            C2
# 23              B2             63            C1
# 24              B2             68            C1
# 25              C1             59            B2
# 26              B2             65            C1
# 27              C1             73            C2
# 28              C1             75            C2
# 29              C2             72            C2

# %%
# Getting the percentage of each CEFR level in the population
perc = round((df['CEFR_level'].value_counts()/len(df))*100,2)

# Lets create a Series object with the index as the CEFR levels and the values as the percentage
cefr = pd.Series(perc.values, index=perc.index)

# Rename the column names to Score %
cefr.rename('Score %', inplace=True)
cefr.sort_values(ascending=True, inplace=True)
cefr
# Out:
# CEFR_level
# A1     3.33
# A2    10.00
# C2    10.00
# B1    16.67
# B2    20.00
# C1    40.00
# Name: Score %, dtype: float64

# %%
# Plotting interactive plots with plotly
cefr.iplot(kind='bar', title='CEFR Level vs Score %')
# Out:
# <div>                            <div id="b0b4168b-2ede-4179-a242-0c8f28f7c7a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("b0b4168b-2ede-4179-a242-0c8f28f7c7a0")) {                    Plotly.newPlot(                        "b0b4168b-2ede-4179-a242-0c8f28f7c7a0",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"Score %","orientation":"v","text":"","x":["A1","A2","C2","B1","B2","C1"],"y":[3.33,10.0,10.0,16.67,20.0,40.0],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0," ...

# %%
df[df['CEFR_level']=='C2']
# Out:
#                Name  EF_Score CEFR_level  Listening_score Listening_scale  \
# 27     Jayashri B.S        72         C2               68              C1
# 28  JOSELIN REINA J        71         C2               68              C1
# 29  Bernita Celas C        72         C2               72              C2
#
#     Reading_score Reading_scale
# 27             75            C2
# 28             73            C2
# 29             72            C2

# %%
sns.countplot(x='CEFR_level', data=df)
# Out:
# <Axes: xlabel='CEFR_level', ylabel='count'>

# %%
# Finding the average of each CEFR level
cefr_ef_mean = df.groupby('CEFR_level')['EF_Score'].mean()
cefr_ef_mean
# Out:
# CEFR_level
# A1    30.000000
# A2    35.666667
# B1    47.800000
# B2    55.833333
# C1    64.666667
# C2    71.666667
# Name: EF_Score, dtype: float64

# %%
# Plotting the boxplot for each CEFR level
sns.boxplot(x='CEFR_level', y='EF_Score', data=df)
# Out:
# <Axes: xlabel='CEFR_level', ylabel='EF_Score'>

# %%
df.columns
# Out:
# Index(['Name', 'EF_Score', 'CEFR_level', 'Listening_score', 'Listening_scale',
#        'Reading_score', 'Reading_scale'],
#       dtype='object')

# %%
# Plotting the distribution of the EF_Score
sns.displot(df['EF_Score'], kde=True)
# Out:
# /Users/kausik/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.groupby('CEFR_level')['EF_Score'].describe()[['mean','std','min','25%','50%','75%','max']],annot=True,cmap='rainbow',alpha=1.0)
plt.xlabel("Statistical Measures")
plt.ylabel("CEFR Levels")
plt.title("Statistical Measures for each CEFR Level")
# Out:
# Text(0.5, 1.0, 'Statistical Measures for each CEFR Level')

# %%
# Plotting the distribution of the EF_Score for each CEFR level
plt.figure(figsize=(10,6))
sns.boxplot(x='CEFR_level', y='EF_Score', data=df)
plt.xlabel("CEFR Levels")
plt.ylabel("EF Score")
# Out:
# Text(0, 0.5, 'EF Score')

# %%
# Plotting the distrinution of the EF_Score with respect to the CEFR level on a line plot
# Let's plot a line plot wheere each CEFR Level is a line having a seperate color
plt.figure(figsize=(10,6))
sns.lineplot(x='CEFR_level', y='EF_Score', data=df, hue='CEFR_level')
plt.xlabel("CEFR Levels")
plt.ylabel("EF Score")
# Out:
# Text(0, 0.5, 'EF Score')

# %%
df["E"]

# %%
# Plotting the distrinution of the EF_Score with respect to the CEFR level on a line plot
# Create a dictionary to map CEFR levels to colors
cefr_colors = {
    'A1': 'red',
    'A2': 'orange',
    'B1': 'yellow',
    'B2': 'green',
    'C1': 'blue',
    'C2': 'purple'
}

# Create a line plot for each CEFR level with a different color
for level, color in cefr_colors.items():
    level_data = df[df['CEFR_level'] == level]
    plt.plot(level_data['EF_Score'], label=level, color=color, marker='o')

# Set plot labels and legend
plt.xlabel('EF Scores')
plt.ylabel('CEFR Level')
plt.legend()

# Display the plot
plt.show()

# %%
df.columns
# Out:
# Index(['Name', 'EF_Score', 'CEFR_level', 'Listening_score', 'Listening_scale',
#        'Reading_score', 'Reading_scale'],
#       dtype='object')

# %%
# Plotting the distribution of Listening Score with the listening scale 
plt.figure(figsize=(10,6))
sns.countplot(x='Listening_score', data=df)
# Out:
# <Axes: xlabel='Listening_score', ylabel='count'>

# %%
# Lets plot a heatmap for the correlation between the different columns
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='rainbow', alpha=1.0)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Name', 'EF_Score', 'CEFR_level', 'Listening_score', 'Listening_scale',
#        'Reading_score', 'Reading_scale'],
#       dtype='object')

# %%
# Lets plot a distribution plot between the EF_Score and the Listening Score
plt.figure(figsize=(10,6))
sns.displot(x=df["EF_Score"], kde=True)
# Out:
# /Users/kausik/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
sns.lmplot(x='EF_Score', y='Listening_score', data=df)
# Out:
# /Users/kausik/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
# Lets plot a distribution plot between the EF_Score and the Reading Score
plt.figure(figsize=(10,6))
sns.lmplot(x='EF_Score', y='Reading_score', data=df)
# Out:
# /Users/kausik/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
